# %%
import pandas as pd
data1 = pd.read_csv('discentes-2009.csv',sep=";")
data2 = pd.read_csv('discentes-2010.csv',sep=";")
data3 = pd.read_csv('discentes-2011.csv',sep=";")
data4 = pd.read_csv('discentes-2012.csv',sep=";")
data5 = pd.read_csv('discentes-2013.csv',sep=";")
data6 = pd.read_csv('discentes-2014.csv',sep=";")
data7 = pd.read_csv('discentes-2015.csv',sep=";")
data8 = pd.read_csv('discentes-2016.csv',sep=";")
data9 = pd.read_csv('discentes-2017.csv',sep=";")
data10 = pd.read_csv('discentes-2018.csv',sep=";")
data11 = pd.read_csv('discentes-2019.csv',sep=";")
discentes = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11])

# %% [markdown]
# **CURSOS GRADUAÇÃO(SEXO)**

# %% [markdown]
# **CT**

# %%
EALI = discentes.loc[discentes["nome_curso"] == "ENGENHARIA DE ALIMENTOS"]
sns.countplot(data=EALI,x="ano_ingresso",hue="sexo")
plt.show()

# %%
AURB = discentes.loc[discentes["nome_curso"] == "ARQUITETURA E URBANISMO"]
sns.countplot(data=AURB,x="ano_ingresso",hue="sexo")
plt.show()

# %%
ECIV = discentes.loc[discentes["nome_curso"] == "ENGENHARIA CIVIL"]
sns.countplot(data=ECIV,x="ano_ingresso",hue="sexo")
plt.show()

# %%
EELE = discentes.loc[discentes["nome_curso"] == "ENGENHARIA ELÉTRICA"]
sns.countplot(data=EELE,x="ano_ingresso",hue="sexo")
plt.show()

# %%
EMAT = discentes.loc[discentes["nome_curso"] == "ENGENHARIA DE MATERIAIS"]
sns.countplot(data=EMAT,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **CB**

# %%
BIO = discentes.loc[discentes["nome_curso"] == "BIOMEDICINA"]
sns.countplot(data=BIO,x="ano_ingresso",hue="sexo")
plt.show()

# %%
ECO = discentes.loc[discentes["nome_curso"] == "ECOLOGIA"]
sns.countplot(data=ECO,x="ano_ingresso",hue="sexo")
plt.show()

# %%
CBIO = discentes.loc[discentes["nome_curso"] == "CIÊNCIAS BIOLÓGICAS"]
sns.countplot(data=CBIO,x="ano_ingresso",hue="sexo")
plt.show()

# %%
EAQUI = discentes.loc[discentes["nome_curso"] == "ENGENHARIA DE AQUICULTURA"]
sns.countplot(data=EAQUI,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **CCS**

# %%
MED = discentes.loc[discentes["nome_curso"] == "MEDICINA"]
sns.countplot(data=MED,x="ano_ingresso",hue="sexo")
plt.show()

# %%
ENF = discentes.loc[discentes["nome_curso"] == "ENFERMAGEM"]
sns.countplot(data=ENF,x="ano_ingresso",hue="sexo")
plt.show()

# %%
FISIO = discentes.loc[discentes["nome_curso"] == "FISIOTERAPIA"]
sns.countplot(data=FISIO,x="ano_ingresso",hue="sexo")
plt.show()

# %%
NUTRI = discentes.loc[discentes["nome_curso"] == "NUTRIÇÃO"]
sns.countplot(data=NUTRI,x="ano_ingresso",hue="sexo")
plt.show()

# %%
ODO = discentes.loc[discentes["nome_curso"] == "ODONTOLOGIA"]
sns.countplot(data=ODO,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **CCET**

# %%
GEO = discentes.loc[discentes["nome_curso"] == "GEOLOGIA"]
sns.countplot(data=GEO,x="ano_ingresso",hue="sexo")
plt.show()

# %%
MET = discentes.loc[discentes["nome_curso"] == "METEOROLOGIA"]
sns.countplot(data=MET,x="ano_ingresso",hue="sexo")
plt.show()

# %%
QUIM = discentes.loc[discentes["nome_curso"] == "QUÍMICA"]
sns.countplot(data=QUIM,x="ano_ingresso",hue="sexo")
plt.show()

# %%
MAT = discentes.loc[discentes["nome_curso"] == "MATEMÁTICA"]
sns.countplot(data=MAT,x="ano_ingresso",hue="sexo")
plt.show()

# %%
FIS = discentes.loc[discentes["nome_curso"] == "FÍSICA"]
sns.countplot(data=FIS,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **CCHLA**

# %%
DAN = discentes.loc[discentes["nome_curso"] == "DANÇA"]
sns.countplot(data=DAN,x="ano_ingresso",hue="sexo")
plt.show()

# %%
DES = discentes.loc[discentes["nome_curso"] == "DESIGN"]
sns.countplot(data=DES,x="ano_ingresso",hue="sexo")
plt.show()

# %%
FILO = discentes.loc[discentes["nome_curso"] == "FILOSOFIA"]
sns.countplot(data=FILO,x="ano_ingresso",hue="sexo")
plt.show()

# %%
TEAT = discentes.loc[discentes["nome_curso"] == "TEATRO"]
sns.countplot(data=TEAT,x="ano_ingresso",hue="sexo")
plt.show()

# %%
LET = discentes.loc[discentes["nome_curso"] == "LETRAS"]
sns.countplot(data=LET,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **CCSA**

# %%
ADM = discentes.loc[discentes["nome_curso"] == "ADMINISTRAÇÃO"]
sns.countplot(data=ADM,x="ano_ingresso",hue="sexo")
plt.show()

# %%
CCONT = discentes.loc[discentes["nome_curso"] == "CIÊNCIAS CONTÁBEIS"]
sns.countplot(data=CCONT,x="ano_ingresso",hue="sexo")
plt.show()

# %%
TUR = discentes.loc[discentes["nome_curso"] == "TURISMO"]
sns.countplot(data=TUR,x="ano_ingresso",hue="sexo")
plt.show()

# %%
DIR = discentes.loc[discentes["nome_curso"] == "DIREITO"]
sns.countplot(data=DIR,x="ano_ingresso",hue="sexo")
plt.show()

# %%
SER = discentes.loc[discentes["nome_curso"] == "SERVIÇO SOCIAL"]
sns.countplot(data=SER,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **CE**

# %%
PED = discentes.loc[discentes["nome_curso"] == "PEDAGOGIA"]
sns.countplot(data=PED,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **BTI**

# %%
BTI = discentes.loc[discentes["nome_curso"] == "TECNOLOGIA DA INFORMAÇÃO"]
sns.countplot(data=BTI,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **BCT**

# %%
BCT = discentes.loc[discentes["nome_curso"] == "CIÊNCIAS E TECNOLOGIA"]
sns.countplot(data=BCT,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
#  **CURSOS GRADUAÇÃO(RAÇA)**

# %% [markdown]
# **CT**

# %%
EALI = discentes.loc[discentes["nome_curso"] == "ENGENHARIA DE ALIMENTOS"]
sns.countplot(data=EALI,x="ano_ingresso",hue="raca")
plt.show()

# %%
AURB = discentes.loc[discentes["nome_curso"] == "ARQUITETURA E URBANISMO"]
sns.countplot(data=AURB,x="ano_ingresso",hue="raca")
plt.show()

# %%
ECIV = discentes.loc[discentes["nome_curso"] == "ENGENHARIA CIVIL"]
sns.countplot(data=ECIV,x="ano_ingresso",hue="raca")
plt.show()

# %%
EELE = discentes.loc[discentes["nome_curso"] == "ENGENHARIA ELÉTRICA"]
sns.countplot(data=EELE,x="ano_ingresso",hue="raca")
plt.show()

# %%
EMAT = discentes.loc[discentes["nome_curso"] == "ENGENHARIA DE MATERIAIS"]
sns.countplot(data=EMAT,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **CB**

# %%
BIO = discentes.loc[discentes["nome_curso"] == "BIOMEDICINA"]
sns.countplot(data=BIO,x="ano_ingresso",hue="raca")
plt.show()

# %%
ECO = discentes.loc[discentes["nome_curso"] == "ECOLOGIA"]
sns.countplot(data=ECO,x="ano_ingresso",hue="raca")
plt.show()

# %%
CBIO = discentes.loc[discentes["nome_curso"] == "CIÊNCIAS BIOLÓGICAS"]
sns.countplot(data=CBIO,x="ano_ingresso",hue="raca")
plt.show()

# %%
EAQUI = discentes.loc[discentes["nome_curso"] == "ENGENHARIA DE AQUICULTURA"]
sns.countplot(data=EAQUI,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **CCS**

# %%
MED = discentes.loc[discentes["nome_curso"] == "MEDICINA"]
sns.countplot(data=MED,x="ano_ingresso",hue="raca")
plt.show()

# %%
ENF = discentes.loc[discentes["nome_curso"] == "ENFERMAGEM"]
sns.countplot(data=ENF,x="ano_ingresso",hue="raca")
plt.show()

# %%
FISIO = discentes.loc[discentes["nome_curso"] == "FISIOTERAPIA"]
sns.countplot(data=FISIO,x="ano_ingresso",hue="raca")
plt.show()

# %%
NUTRI = discentes.loc[discentes["nome_curso"] == "NUTRIÇÃO"]
sns.countplot(data=NUTRI,x="ano_ingresso",hue="raca")
plt.show()

# %%
ODO = discentes.loc[discentes["nome_curso"] == "ODONTOLOGIA"]
sns.countplot(data=ODO,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **CCET**

# %%
GEO = discentes.loc[discentes["nome_curso"] == "GEOLOGIA"]
sns.countplot(data=GEO,x="ano_ingresso",hue="raca")
plt.show()

# %%
MET = discentes.loc[discentes["nome_curso"] == "METEOROLOGIA"]
sns.countplot(data=MET,x="ano_ingresso",hue="raca")
plt.show()

# %%
QUIM = discentes.loc[discentes["nome_curso"] == "QUÍMICA"]
sns.countplot(data=QUIM,x="ano_ingresso",hue="raca")
plt.show()

# %%
MAT = discentes.loc[discentes["nome_curso"] == "MATEMÁTICA"]
sns.countplot(data=MAT,x="ano_ingresso",hue="raca")
plt.show()

# %%
FIS = discentes.loc[discentes["nome_curso"] == "FÍSICA"]
sns.countplot(data=FIS,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **CCHLA**

# %%
DAN = discentes.loc[discentes["nome_curso"] == "DANÇA"]
sns.countplot(data=DAN,x="ano_ingresso",hue="raca")
plt.show()

# %%
DES = discentes.loc[discentes["nome_curso"] == "DESIGN"]
sns.countplot(data=DES,x="ano_ingresso",hue="raca")
plt.show()

# %%
FILO = discentes.loc[discentes["nome_curso"] == "FILOSOFIA"]
sns.countplot(data=FILO,x="ano_ingresso",hue="raca")
plt.show()

# %%
TEAT = discentes.loc[discentes["nome_curso"] == "TEATRO"]
sns.countplot(data=TEAT,x="ano_ingresso",hue="raca")
plt.show()

# %%
LET = discentes.loc[discentes["nome_curso"] == "LETRAS"]
sns.countplot(data=LET,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **CCSA**

# %%
ADM = discentes.loc[discentes["nome_curso"] == "ADMINISTRAÇÃO"]
sns.countplot(data=ADM,x="ano_ingresso",hue="raca")
plt.show()

# %%
CCONT = discentes.loc[discentes["nome_curso"] == "CIÊNCIAS CONTÁBEIS"]
sns.countplot(data=CCONT,x="ano_ingresso",hue="raca")
plt.show()

# %%
TUR = discentes.loc[discentes["nome_curso"] == "TURISMO"]
sns.countplot(data=TUR,x="ano_ingresso",hue="raca")
plt.show()

# %%
DIR = discentes.loc[discentes["nome_curso"] == "DIREITO"]
sns.countplot(data=DIR,x="ano_ingresso",hue="raca")
plt.show()

# %%
SER = discentes.loc[discentes["nome_curso"] == "SERVIÇO SOCIAL"]
sns.countplot(data=SER,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **CE**

# %%
PED = discentes.loc[discentes["nome_curso"] == "PEDAGOGIA"]
sns.countplot(data=PED,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **BTI**

# %%
BTI = discentes.loc[discentes["nome_curso"] == "TECNOLOGIA DA INFORMAÇÃO"]
sns.countplot(data=BTI,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **BCT**

# %%
BCT = discentes.loc[discentes["nome_curso"] == "CIÊNCIAS E TECNOLOGIA"]
sns.countplot(data=BCT,x="ano_ingresso",hue="raca")
plt.show()

# %% [markdown]
# **CURSOS PÓS-GRADUAÇÃO(SEXO)**

# %%
import pandas as pd
PPgEEC = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"]
sns.countplot(data=PPgEEC,x="ano_ingresso",hue="sexo")
plt.show()

# %%
import pandas as pd
PPgSC = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"]
sns.countplot(data=PPgSC,x="ano_ingresso",hue="sexo")
plt.show()

# %%
import pandas as pd
PPgSW = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"]
sns.countplot(data=PPgSW,x="ano_ingresso",hue="sexo")
plt.show()

# %%
import pandas as pd
PPgITE = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM INOVAÇÃO EM TECNOLOGIAS EDUCACIONAIS"]
sns.countplot(data=PPgITE,x="ano_ingresso",hue="sexo")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
PPgBIOINF = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"]
sns.countplot(data=PPgBIOINF,x="ano_ingresso",hue="sexo")
plt.show()

# %% [markdown]
# **CURSOS PÓS-GRADUAÇÃO(RAÇA)**

# %%
BTI = discentes.loc[discentes["nome_curso"] == "TECNOLOGIA DA INFORMAÇÃO"]
sns.countplot(data=BTI,x="ano_ingresso",hue="raca")
plt.show()

# %%
BCT = discentes.loc[discentes["nome_curso"] == "CIÊNCIAS E TECNOLOGIA"]
sns.countplot(data=BTI,x="ano_ingresso",hue="raca")
plt.show()

# %%
PPgEEC = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA ELÉTRICA E DE COMPUTAÇÃO"]
sns.countplot(data=PPgEEC,x="ano_ingresso",hue="raca")
plt.show()

# %%
PPgSC = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM SISTEMAS E COMPUTAÇÃO"]
sns.countplot(data=PPgSC,x="ano_ingresso",hue="raca")
plt.show()

# %%
PPgSW = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM ENGENHARIA DE SOFTWARE"]
sns.countplot(data=PPgSW,x="ano_ingresso",hue="raca")
plt.show()

# %%
PPgITE = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM INOVAÇÃO EM TECNOLOGIAS EDUCACIONAIS"]
sns.countplot(data=PPgITE,x="ano_ingresso",hue="raca")
plt.show()

# %%
PPgBIOINF = discentes.loc[discentes["nome_unidade"] == "PROGRAMA DE PÓS-GRADUAÇÃO EM BIOINFORMÁTICA"]
sns.countplot(data=PPgBIOINF,x="ano_ingresso",hue="raca")
plt.show()
